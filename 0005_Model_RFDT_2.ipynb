# %%
import sys
import pandas as pd 
import numpy as np
#np.set_printoptions(threshold=sys.maxsize)
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob
import plotly.express as px
# %matplotlib inline

# %%
# %%time
os.chdir(r'../data/extracted/')
all_files=glob.glob('*csv')
print(all_files)
# Out:
# ['big_testS.csv', 'big_trainS.csv']
# CPU times: total: 0 ns
# Wall time: 997 µs

# %% [markdown]
# big_train_df.to_csv('big_trainS.csv', index=False)
# big_test_df.to_csv('big_testS.csv', index=False)

# %%
big_train_df=pd.read_csv('big_trainS.csv')
big_test_df=pd.read_csv('big_testS.csv')

# %%
big_train_df
# Out:
#       ('acceleration_CROSS', 'max')  ('acceleration_CROSS', 'mean')  \
# 0                          0.489770                        0.000342
# 1                          0.210257                        0.000087
# 2                          0.079985                       -0.000017
# 3                          0.791746                        0.000015
# 4                          0.376787                        0.000171
# ...                             ...                             ...
# 9835                       0.394229                        0.000030
# 9836                       0.164526                        0.000003
# 9837                       0.397226                       -0.000041
# 9838                       0.786963                        0.000094
# 9839                       0.093619                        0.000010
#
#       ('acceleration_CROSS', 'median')  ('acceleration_CROSS', 'min')  \
# 0                            -0.000278                      -0.494049
# 1                            -0.000029                      -0.197432
# 2                            -0.000083                      -0.083063
# 3                             0.002515                      -0.796901
# 4                             0.000807                      -0.350226
# ...                                ...                            ...
# 9835                          0.001652                      -0.397220
# 9836                          0.000555                      -0.164477
# 9837                          0.000139                      -0.470158
# 9838                          0.002306                      -0.719794
# 9839                          0.000333                      -0.087982
#
#       ('acceleration_CROSS', 'q1')  ('acceleration_CROSS', 'q3')  \
# 0                        -0.114564                      0.112878
# 1                        -0.035254                      0.034571
# 2                        -0.011903                      0.011633
# 3                        -0.157288                      0.157761
# 4                        -0.055987                      0.056059
# ...                            ...                           ...
# 9835                     -0.075757                      0.075310
# 9836                     -0.029385                      0.028586
# 9837                     -0.084217                      0.083207
# 9838                     -0.116239                      0.118354
# 9839                     -0.014617                      0.014217
#
#       ('acceleration_CROSS', 'std')  ('acceleration_THRUST', 'max')  \
# 0                          0.161595                        0.741513
# 1                          0.051819                        0.369274
# 2                          0.019291                        0.166660
# 3                          0.240002                        1.066662
# 4                          0.085426                        0.514496
# ...                             ...                             ...
# 9835                       0.112598                        0.617068
# 9836                       0.042413                        0.270527
# 9837                       0.119152                        0.647171
# 9838                       0.174033                        1.468019
# 9839                       0.023925                        0.172973
#
#       ('acceleration_THRUST', 'mean')  ('acceleration_THRUST', 'median')  ...  \
# 0                            0.000051                          -0.001924  ...
# 1                           -0.000003                           0.000421  ...
# 2                            0.000019                           0.000196  ...
# 3                           -0.000132                           0.001431  ...
# 4                           -0.000117                           0.000354  ...
# ...                               ...                                ...  ...
# 9835                        -0.000127                          -0.001125  ...
# 9836                         0.000013                           0.000960  ...
# 9837                         0.000213                           0.003176  ...
# 9838                        -0.000007                           0.000902  ...
# 9839                         0.000102                          -0.000049  ...
#
#       ('rotorposition', 'max')  ('rotorposition', 'mean')  \
# 0                   359.965851                 179.649152
# 1                   359.964172                 180.236180
# 2                   359.994171                 180.033284
# 3                   359.974792                 179.692008
# 4                   359.999481                 179.772392
# ...                        ...                        ...
# 9835                359.965271                 179.758451
# 9836                359.999084                 180.056015
# 9837                359.994934                 179.724181
# 9838                359.942108                 179.704399
# 9839                359.953949                 179.866777
#
#       ('rotorposition', 'median')  ('rotorposition', 'min')  \
# 0                      179.409241                  0.000000
# 1                      180.398285                  0.022498
# 2                      179.974594                  0.022500
# 3                      179.503677                  0.011249
# 4                      179.639740                  0.011250
# ...                           ...                       ...
# 9835                   179.656418                  0.000000
# 9836                   179.943298                  0.056250
# 9837                   179.614975                  0.011250
# 9838                   179.464890                  0.011248
# 9839                   179.796997                  0.022497
#
#       ('rotorposition', 'q1')  ('rotorposition', 'q3')  \
# 0                   89.575256               269.423187
# 1                   90.238518               270.164368
# 2                   90.313538               269.770630
# 3                   89.903709               269.654877
# 4                   89.943619               269.594604
# ...                       ...                      ...
# 9835                89.788834               269.692719
# 9836                90.247269               269.965576
# 9837                89.829987               269.343719
# 9838                89.681824               269.709106
# 9839                89.729767               269.954193
#
#       ('rotorposition', 'std')  wind_speed  yaw_error  turbulence
# 0                   103.831344   20.066645   0.164071    0.100937
# 1                   103.880212    8.013724  -0.182137    0.126556
# 2                   103.759796    6.514676  -0.014293    0.070146
# 3                   103.866017   18.137805  -0.016715    0.158380
# 4                   103.824510   16.061122   0.155939    0.096964
# ...                        ...         ...        ...         ...
# 9835                103.821885   20.547543  20.133675    0.080709
# 9836                103.849783    8.461993  20.194643    0.083262
# 9837                103.832521   19.088741  19.980330    0.086115
# 9838                103.911023   16.682702  19.967373    0.152966
# 9839                104.002736    4.554761  19.918157    0.089087
#
# [9840 rows x 73 columns]

# %%
big_test_df
# Out:
#       ('acceleration_CROSS', 'max')  ('acceleration_CROSS', 'mean')  \
# 0                          0.290710                       -0.000144
# 1                          0.406804                       -0.000070
# 2                          0.553435                        0.000117
# 3                          0.252573                       -0.000163
# 4                          0.826334                        0.000075
# ...                             ...                             ...
# 2455                       0.477714                       -0.000342
# 2456                       0.494386                       -0.000315
# 2457                       0.396391                        0.000072
# 2458                       0.273828                       -0.000200
# 2459                       0.395943                       -0.000325
#
#       ('acceleration_CROSS', 'median')  ('acceleration_CROSS', 'min')  \
# 0                             0.000759                      -0.325755
# 1                             0.001854                      -0.385521
# 2                             0.000876                      -0.540282
# 3                             0.000598                      -0.287330
# 4                             0.002711                      -0.820395
# ...                                ...                            ...
# 2455                         -0.000374                      -0.480238
# 2456                         -0.000621                      -0.421256
# 2457                         -0.000108                      -0.396850
# 2458                         -0.000490                      -0.262840
# 2459                         -0.001915                      -0.409773
#
#       ('acceleration_CROSS', 'q1')  ('acceleration_CROSS', 'q3')  \
# 0                        -0.055042                      0.056361
# 1                        -0.092085                      0.091313
# 2                        -0.147409                      0.145844
# 3                        -0.047321                      0.047238
# 4                        -0.160205                      0.161755
# ...                            ...                           ...
# 2455                     -0.097020                      0.096085
# 2456                     -0.090722                      0.089481
# 2457                     -0.067863                      0.067971
# 2458                     -0.053611                      0.053086
# 2459                     -0.082728                      0.084536
#
#       ('acceleration_CROSS', 'std')  ('acceleration_THRUST', 'max')  \
# 0                          0.086448                        0.537324
# 1                          0.125427                        0.763394
# 2                          0.191594                        0.740504
# 3                          0.072673                        0.481277
# 4                          0.239655                        1.153420
# ...                             ...                             ...
# 2455                       0.140415                        1.004360
# 2456                       0.130363                        0.921714
# 2457                       0.100109                        0.901861
# 2458                       0.076717                        0.461016
# 2459                       0.122122                        0.639102
#
#       ('acceleration_THRUST', 'mean')  ('acceleration_THRUST', 'median')  ...  \
# 0                            0.000146                          -0.000704  ...
# 1                            0.000212                           0.001846  ...
# 2                           -0.000072                          -0.002848  ...
# 3                            0.000059                          -0.000609  ...
# 4                           -0.000115                          -0.000538  ...
# ...                               ...                                ...  ...
# 2455                        -0.000239                          -0.002211  ...
# 2456                        -0.000334                           0.001641  ...
# 2457                         0.000179                          -0.001978  ...
# 2458                        -0.000164                           0.000801  ...
# 2459                         0.000094                          -0.001584  ...
#
#       ('rotorposition', 'max')  ('rotorposition', 'mean')  \
# 0                   360.000000                 179.870725
# 1                   359.958679                 179.725069
# 2                   359.969147                 179.738295
# 3                   359.998322                 179.823805
# 4                   359.986084                 179.597812
# ...                        ...                        ...
# 2455                359.999573                 179.726937
# 2456                359.994537                 179.958009
# 2457                359.991150                 179.802036
# 2458                359.990204                 179.838955
# 2459                359.980011                 179.894748
#
#       ('rotorposition', 'median')  ('rotorposition', 'min')  \
# 0                      179.741257                  0.022500
# 1                      179.428146                  0.022497
# 2                      179.568359                  0.044996
# 3                      179.717911                  0.011250
# 4                      179.329330                  0.011250
# ...                           ...                       ...
# 2455                   179.504791                  0.033750
# 2456                   179.884766                  0.078749
# 2457                   179.590591                  0.033749
# 2458                   179.758865                  0.000000
# 2459                   179.731277                  0.011249
#
#       ('rotorposition', 'q1')  ('rotorposition', 'q3')  \
# 0                   90.000000               269.606262
# 1                   89.663460               269.541565
# 2                   89.913544               269.493134
# 3                   89.853333               269.593750
# 4                   89.704033               269.517090
# ...                       ...                      ...
# 2455                89.831139               269.695923
# 2456                90.066132               269.770905
# 2457                89.896545               269.655884
# 2458                89.975052               269.621429
# 2459                90.152496               269.647522
#
#       ('rotorposition', 'std')  wind_speed  yaw_error  turbulence
# 0                   103.840285   16.065554   0.028640    0.097224
# 1                   103.896900   14.203022   0.140276    0.150162
# 2                   103.836321   21.991639  -0.137009    0.080451
# 3                   103.844936   14.062233   0.033725    0.103931
# 4                   103.880775   18.649035  -0.018371    0.163043
# ...                        ...         ...        ...         ...
# 2455                103.866634   15.874465  20.173493    0.156215
# 2456                103.851656   17.787865  20.008807    0.141018
# 2457                103.879832   13.863452  20.202762    0.133903
# 2458                103.834209   19.132481  20.011264    0.071423
# 2459                103.819171   20.372886  19.921642    0.080007
#
# [2460 rows x 73 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, f1_score



X_train = big_train_df.drop(['wind_speed', 'yaw_error', 'turbulence'], axis=1)
y_train = big_train_df['wind_speed']

X_test = big_test_df.drop(['wind_speed', 'yaw_error', 'turbulence'], axis=1)
y_test = big_test_df['wind_speed']

rf_model = RandomForestRegressor(n_estimators=100)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

dt_model = DecisionTreeRegressor()
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

rf_mae = mean_absolute_error(y_test, y_pred_rf)
rf_mse = mean_squared_error(y_test, y_pred_rf)
rf_rmse = np.sqrt(rf_mse)
rf_r2 = r2_score(y_test, y_pred_rf)

dt_mae = mean_absolute_error(y_test, y_pred_dt)
dt_mse = mean_squared_error(y_test, y_pred_dt)
dt_rmse = np.sqrt(dt_mse)
dt_r2 = r2_score(y_test, y_pred_dt)

print('Random Forest Metrics:')
print('MAE:', rf_mae)
print('MSE:', rf_mse)
print('RMSE:', rf_rmse)
print('R2 Score:', rf_r2)
print('-----------------------------')
print('Decision Tree Metrics:')
print('MAE:', dt_mae)
print('MSE:', dt_mse)
print('RMSE:', dt_rmse)
print('R2 Score:', dt_r2)
# Out:
# Random Forest Metrics:
# MAE: 0.2944717725441581
# MSE: 0.15391365578581975
# RMSE: 0.3923183092666206
# R2 Score: 0.9952220215800422
# -----------------------------
# Decision Tree Metrics:
# MAE: 0.36316564276167046
# MSE: 0.2650565001817972
# RMSE: 0.5148363819523609
# R2 Score: 0.991771787685295

# %%
# Plotting the results
plt.figure(figsize=(10, 6))

# Random Forest
plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred_rf, color='blue', alpha=0.3)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual Wind Speed')
plt.ylabel('Predicted Wind Speed')
plt.title('Random Forest: Actual vs. Predicted')

# Decision Tree
plt.subplot(1, 2, 2)
plt.scatter(y_test, y_pred_dt, color='red', alpha=0.3)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual Wind Speed')
plt.ylabel('Predicted Wind Speed')
plt.title('Decision Tree: Actual vs. Predicted')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, f1_score



X_train = big_train_df.drop(['wind_speed', 'yaw_error', 'turbulence'], axis=1)
y_train = big_train_df['yaw_error']

X_test = big_test_df.drop(['wind_speed', 'yaw_error', 'turbulence'], axis=1)
y_test = big_test_df['yaw_error']

rf_model = RandomForestRegressor(n_estimators=100)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

dt_model = DecisionTreeRegressor()
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

rf_mae = mean_absolute_error(y_test, y_pred_rf)
rf_mse = mean_squared_error(y_test, y_pred_rf)
rf_rmse = np.sqrt(rf_mse)
rf_r2 = r2_score(y_test, y_pred_rf)

dt_mae = mean_absolute_error(y_test, y_pred_dt)
dt_mse = mean_squared_error(y_test, y_pred_dt)
dt_rmse = np.sqrt(dt_mse)
dt_r2 = r2_score(y_test, y_pred_dt)

print('Random Forest Metrics:')
print('MAE:', rf_mae)
print('MSE:', rf_mse)
print('RMSE:', rf_rmse)
print('R2 Score:', rf_r2)
print('-----------------------------')
print('Decision Tree Metrics:')
print('MAE:', dt_mae)
print('MSE:', dt_mse)
print('RMSE:', dt_rmse)
print('R2 Score:', dt_r2)


plt.figure(figsize=(10, 6))

plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred_rf, color='blue', alpha=0.3)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual yaw_error')
plt.ylabel('Predicted yaw_error')
plt.title('Random Forest: Actual vs. Predicted')

plt.subplot(1, 2, 2)
plt.scatter(y_test, y_pred_dt, color='red', alpha=0.3)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual yaw_error')
plt.ylabel('Predicted yaw_error')
plt.title('Decision Tree: Actual vs. Predicted')

plt.tight_layout()
plt.show()
# Out:
# Random Forest Metrics:
# MAE: 6.469061993531321
# MSE: 73.76813977616887
# RMSE: 8.588838092324762
# R2 Score: 0.4732260671326155
# -----------------------------
# Decision Tree Metrics:
# MAE: 9.036464933867817
# MSE: 164.67815408276118
# RMSE: 12.832698628221625
# R2 Score: -0.175956980164242

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, f1_score



X_train = big_train_df.drop(['wind_speed', 'yaw_error', 'turbulence'], axis=1)
y_train = big_train_df['turbulence']

X_test = big_test_df.drop(['wind_speed', 'yaw_error', 'turbulence'], axis=1)
y_test = big_test_df['turbulence']

rf_model = RandomForestRegressor(n_estimators=100)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

dt_model = DecisionTreeRegressor()
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

rf_mae = mean_absolute_error(y_test, y_pred_rf)
rf_mse = mean_squared_error(y_test, y_pred_rf)
rf_rmse = np.sqrt(rf_mse)
rf_r2 = r2_score(y_test, y_pred_rf)

dt_mae = mean_absolute_error(y_test, y_pred_dt)
dt_mse = mean_squared_error(y_test, y_pred_dt)
dt_rmse = np.sqrt(dt_mse)
dt_r2 = r2_score(y_test, y_pred_dt)

print('Random Forest Metrics:')
print('MAE:', rf_mae)
print('MSE:', rf_mse)
print('RMSE:', rf_rmse)
print('R2 Score:', rf_r2)
print('-----------------------------')
print('Decision Tree Metrics:')
print('MAE:', dt_mae)
print('MSE:', dt_mse)
print('RMSE:', dt_rmse)
print('R2 Score:', dt_r2)


plt.figure(figsize=(10, 6))

plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred_rf, color='blue', alpha=0.3)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual turbulence')
plt.ylabel('Predicted turbulence')
plt.title('Random Forest: Actual vs. Predicted')

plt.subplot(1, 2, 2)
plt.scatter(y_test, y_pred_dt, color='red', alpha=0.3)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual turbulence')
plt.ylabel('Predicted turbulence')
plt.title('Decision Tree: Actual vs. Predicted')

plt.tight_layout()
plt.show()
# Out:
# Random Forest Metrics:
# MAE: 0.004855761202425847
# MSE: 4.073522131812388e-05
# RMSE: 0.00638241500672934
# R2 Score: 0.9554394050046541
# -----------------------------
# Decision Tree Metrics:
# MAE: 0.00627451789297353
# MSE: 8.281120487798582e-05
# RMSE: 0.009100066201846327
# R2 Score: 0.9094121391209248
